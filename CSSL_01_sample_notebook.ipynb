# %% [markdown]
# <a href="https://colab.research.google.com/github/bhanu151/computational-statistics-course/blob/main/CSSL_01_sample_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello class")
# Out:
# hello class

# %% [markdown]
# Deleted import matplotlib

# %%
a = 5
b= 10
c= a+b
c
# Out:
# 15

# %% [markdown]
# We are learning about computational statistics in this cours

# %%
ad_expense = [10,20,50,41,51]
sales = [500, 750, 932, 1140, 1298]
plt.plot(ad_expense, sales)
# this is a comment
